# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from train_utils import make_pump
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Train and Eval
# - [ ] generate test set indices
# - [ ] train with new data
# - [ ] Evaluation

# %% [markdown]
# ## Data Augment
# - [ ] Data augmentation on a single pair of datum
# - [ ] Generalize data augmentation

# %% [markdown]
# ## GuitarSet Data
# - [x] How to use comp and solo?
# - [x] Evaluate on solo, and mix separately
# - [x] Regenerate data for mixture via prepare

# %% [markdown]
# ## Prepare AMAPs
# - [x] Download AMAPS
# - [x] Prepares them into audio files and jams files
# - [x] Run through prepare
# - [x] Test current models (madmom and crema) on AMAPs and get some numbers

# %%
AMAPS_ROOT = '/Users/tom/Music/A-MAPS/'

# %%
import glob, os, json
import pandas as pd
import pretty_midi as pm
import numpy as np
import jams
import librosa
import tqdm
import soundfile

# %%
def make_amaps_index(amaps_root):
    midi_files = glob.glob(os.path.join(amaps_root, '*.mid'))
    wav_files = glob.glob(os.path.join(amaps_root, '*.wav'))
    track_ids = sorted([os.path.basename(f).split('.')[0] for f in midi_files])
    
    amaps_index = {}
    for track_id in track_ids:
        amaps_index[track_id] = {
            'audio': '{}.wav'.format(track_id),
            'midi': '{}.mid'.format(track_id),
            'jams': '{}.jams'.format(track_id)
        }
        
    return amaps_index

# %%
amaps_index = make_amaps_index(AMAPS_ROOT)

# %%
amaps_df = pd.DataFrame(data=amaps_index).T
amaps_df.to_json('dataset_indecies/amaps_index.json')

# %%
pieces = {}
for raw_idx in amaps_df.index:
    idx_string_list = raw_idx.split('_')
    version = idx_string_list.pop()
    idx = '_'.join(idx_string_list)
    try:
        pieces[idx].append(version)
    except KeyError:
        pieces[idx] = [version]

# %%
len(pieces)
# Out:
# 158

# %%
spliter = ShuffleSplit(n_splits=1, test_size=0.2, random_state=20190921)

# %%
train_idx, test_idx = next(spliter.split(pieces))
train_pieces = np.asarray(sorted(pieces.keys()))[train_idx]
test_pieces = np.asarray(sorted(pieces.keys()))[test_idx]

# %%
amaps_train_idx = []
amaps_test_idx = []

for piece in test_pieces:
    for version in pieces[piece]:
        amaps_test_idx.append('_'.join([piece, version]))
        
for piece in train_pieces:
    for version in pieces[piece]:
        amaps_train_idx.append('_'.join([piece, version]))

# %%
len(amaps_train_idx), len(amaps_test_idx)
# Out:
# (216, 50)

# %%
with open('dataset_indecies/amaps_train_idx.json', 'w') as fp:
    json.dump(amaps_train_idx, fp, indent=2)
    
with open('dataset_indecies/amaps_val_idx.json', 'w') as fp:
    json.dump(amaps_test_idx, fp, indent=2)

# %% [markdown]
# ### Clean up guitarset_index

# %%
gs_df = pd.read_json('dataset_indecies/guitarset_index.json').T

# %%
gs_solo_df = gs_df.filter(like='solo', axis=0).filter(items=['audio_mic', 'audio_mix', 'jams'])
gs_solo_df.rename(columns={'audio_mic': 'audio_mic_solo',
                           'audio_mix': 'audio_mix_solo',
                           'jams': 'jams_solo'},
                  index=lambda x: x[:-5],
                  inplace=True)

gs_solo_df = gs_solo_df.applymap(lambda x: x[0])

# %%
gs_comp_df = gs_df.filter(like='comp', axis=0).filter(items=['audio_mic', 'audio_mix', 'jams'])
gs_comp_df.rename(columns={'audio_mic': 'audio_mic_comp',
                           'audio_mix': 'audio_mix_comp',
                           'jams': 'jams_comp'},
                  index=lambda x: x[:-5],
                  inplace=True)

gs_comp_df = gs_comp_df.applymap(lambda x: x[0])

# %%
gs_df = gs_comp_df.join(gs_solo_df)
# Out:
#                                           audio_mic_comp  \
# 00_BN1-129-Eb  audio_mono-mic/00_BN1-129-Eb_comp_mic.wav
# 00_BN1-147-Gb  audio_mono-mic/00_BN1-147-Gb_comp_mic.wav
# 00_BN2-131-B    audio_mono-mic/00_BN2-131-B_comp_mic.wav
# 00_BN2-166-Ab  audio_mono-mic/00_BN2-166-Ab_comp_mic.wav
# 00_BN3-119-G    audio_mono-mic/00_BN3-119-G_comp_mic.wav
# ...                                                  ...
# 05_SS1-68-E      audio_mono-mic/05_SS1-68-E_comp_mic.wav
# 05_SS2-107-Ab  audio_mono-mic/05_SS2-107-Ab_comp_mic.wav
# 05_SS2-88-F      audio_mono-mic/05_SS2-88-F_comp_mic.wav
# 05_SS3-84-Bb    audio_mono-mic/05_SS3-84-Bb_comp_mic.wav
# 05_SS3-98-C      audio_mono-mic/05_SS3-98-C_comp_mic.wav
#
#                                                  audio_mix_comp  \
# 00_BN1-129-Eb  audio_mono-pickup_mix/00_BN1-129-Eb_comp_mix.wav
# 00_BN1-147-Gb  audio_mono-pickup_mix/00_BN1-147-Gb_comp_mix.wav
# 00_BN2-131-B    audio_mono-pickup_mix/00_BN2-131-B_comp_mix.wav
# 00_BN2-166-Ab  audio_mono-pickup_mix/00_BN2-166-Ab_comp_mix.wav
# 00_BN3-119-G    audio_mono-pickup_mix/00_BN3-119-G_comp_mix.wav
# ...                                                         ...
# 05_SS1-68-E      audio_mono-pickup_mix/05_SS1-68-E_comp_mix.wav
# 05_SS2-107-Ab  audio_mono-pickup_mix/05_SS2-107-Ab_comp_mix.wav
# 05_SS2-88-F      audio_mono-pickup_mix/05_SS2-88-F_comp_mix.wav
# 05_SS3-84-Bb    audio_mono-pickup_mix/05_SS3-84-Bb_comp_mix.wav
# 05_SS3-98-C      audio_mono-pickup_mix/05_SS3-98-C_comp_mix.wav
#
#                                         jams_comp  \
# 00_BN1-129-Eb  annotation/00_BN1-129-Eb_comp.jams
# 00_BN1-147-Gb  annotation/00_BN1-147-Gb_comp.jams
# 00_BN2-131-B    annotation/00_BN2-131-B_comp.jams
# 00_BN2-166-Ab  annotation/00_BN2-166-Ab_comp.jams
# 00_BN3-119-G    annotation/00_BN3-119-G_comp.jams
# ...                                           ...
# 05_SS1-68-E      annotation/05_SS1-68-E_comp.jams
# 05_SS2-107-Ab  annotation/05_SS2-107-Ab_comp.jams
# 05_SS2-88-F      annotation/05_SS2-88-F_comp.jams
# 05_SS3-84-Bb    annotation/05_SS3-84-Bb_comp.jams
# 05_SS3-98-C      annotation/05_SS3-98-C_comp.jams
#
#                                           audio_mic_solo  \
# 00_BN1-129-Eb  audio_mono-mic/00_BN1-129-Eb_solo_mic.wav
# 00_BN1-147-Gb  audio_mono-mic/00_BN1-147-Gb_solo_mic.wav
# 00_BN2-131-B    audio_mono-mic/00_BN2-131-B_solo_mic.wav
# 00_BN2-166-Ab  audio_mono-mic/00_BN2-166-Ab_solo_mic.wav
# 00_BN3-119-G    audio_mono-mic/00_BN3-119-G_solo_mic.wav
# ...                                                  ...
# 05_SS1-68-E      audio_mono-mic/05_SS1-68-E_solo_mic.wav
# 05_SS2-107-Ab  audio_mono-mic/05_SS2-107-Ab_solo_mic.wav
# 05_SS2-88-F      audio_mono-mic/05_SS2-88-F_solo_mic.wav
# 05_SS3-84-Bb    audio_mono-mic/05_SS3-84-Bb_solo_mic.wav
# 05_SS3-98-C      audio_mono-mic/05_SS3-98-C_solo_mic.wav
#
#                                                  audio_mix_solo  \
# 00_BN1-129-Eb  audio_mono-pickup_mix/00_BN1-129-Eb_solo_mix.wav
# 00_BN1-147-Gb  audio_mono-pickup_mix/00_BN1-147-Gb_solo_mix.wav
# 00_BN2-131-B    audio_mono-pickup_mix/00_BN2-131-B_solo_mix.wav
# 00_BN2-166-Ab  audio_mono-pickup_mix/00_BN2-166-Ab_solo_mix.wav
# 00_BN3-119-G    audio_mono-pickup_mix/00_BN3-119-G_solo_mix.wav
# ...                                                         ...
# 05_SS1-68-E      audio_mono-pickup_mix/05_SS1-68-E_solo_mix.wav
# 05_SS2-107-Ab  audio_mono-pickup_mix/05_SS2-107-Ab_solo_mix.wav
# 05_SS2-88-F      audio_mono-pickup_mix/05_SS2-88-F_solo_mix.wav
# 05_SS3-84-Bb    audio_mono-pickup_mix/05_SS3-84-Bb_solo_mix.wav
# 05_SS3-98-C      audio_mono-pickup_mix/05_SS3-98-C_solo_mix.wav
#
#                                         jams_solo
# 00_BN1-129-Eb  annotation/00_BN1-129-Eb_solo.jams
# 00_BN1-147-Gb  annotation/00_BN1-147-Gb_solo.jams
# 00_BN2-131-B    annotation/00_BN2-131-B_solo.jams
# 00_BN2-166-Ab  annotation/00_BN2-166-Ab_solo.jams
# 00_BN3-119-G    annotation/00_BN3-119-G_solo.jams
# ...                                           ...
# 05_SS1-68-E      annotation/05_SS1-68-E_solo.jams
# 05_SS2-107-Ab  annotation/05_SS2-107-Ab_solo.jams
# 05_SS2-88-F      annotation/05_SS2-88-F_solo.jams
# 05_SS3-84-Bb    annotation/05_SS3-84-Bb_solo.jams
# 05_SS3-98-C      annotation/05_SS3-98-C_solo.jams
#
# [180 rows x 6 columns]

# %%
gs_df.to_json(path_or_buf='dataset_indecies/guitarset_index.json')

# %%
amaps_df.to_json(path_or_buf='dataset_indecies/amaps_index.json')

# %% [markdown]
# ### Do GuitarSet Splits

# %%
gs_train_idx, gs_test_idx = next(spliter.split(gs_df.index))
gs_train_pieces = np.asarray(sorted(gs_df.index))[gs_train_idx]
gs_test_pieces = np.asarray(sorted(gs_df.index))[gs_test_idx]

# %%
with open('dataset_indecies/gs_train_idx.json', 'w') as fp:
    json.dump(list(gs_train_pieces), fp, indent=2)
    
with open('dataset_indecies/gs_val_idx.json', 'w') as fp:
    json.dump(list(gs_test_pieces), fp, indent=2)

# %% [markdown]
# ### make jams file from AMAPS midi

# %%
amaps_df.audio['MAPS_MUS-alb_esp2_AkPnCGdD']
# Out:
# 'MAPS_MUS-alb_esp2_AkPnCGdD.wav'

# %%
def midi_to_key_jams(amaps_piece, amaps_df):
    audio_path = os.path.join(AMAPS_ROOT, amaps_df.audio[amaps_piece])
    midi_path = os.path.join(AMAPS_ROOT, amaps_df.midi[amaps_piece])
    jams_path = os.path.join(AMAPS_ROOT, amaps_df.jams[amaps_piece])
    
    audio_dur = librosa.get_duration(filename=audio_path)
    midi = pm.PrettyMIDI(midi_file=midi_path)
    ann = jams.Annotation('key_mode', duration=audio_dur)
    
    # build lists for annotation construction
    start_times = []
    values = []
    for key_sig in midi.key_signature_changes:
        start_times.append(key_sig.time)
        key, mode = pm.key_number_to_key_name(key_sig.key_number).split(' ')
        values.append(':'.join([key, mode.lower()]))

    end_times = start_times[1:] + [audio_dur]
    
    # build annotation
    for st, et, val in zip(start_times, end_times, values):
        ann.append(time=st, duration=et-st, value=val)
        
    # build and save jams
    jam = jams.JAMS(annotations=[ann])
    jam.file_metadata.duration = ann.duration
    jam.file_metadata.title = piece
    jam.save(jams_path)

# %%
for piece in tqdm.tqdm(amaps_df.index):
    midi_to_key_jams(piece, amaps_df)
# Out:
# 100%|██████████| 266/266 [00:32<00:00,  3.55it/s]

# %% [markdown]
# ### Prepare amaps into jams and h5s

# %%
from jams.util import smkdirs
import pumpp
import crema.utils

# %%
def convert(aud, jam, pump, outdir):
    data = pump.transform(aud, jam)
    fname = os.path.extsep.join([os.path.join(outdir, crema.utils.base(aud)),
                                'h5'])
    crema.utils.save_h5(fname, **data)
    
def get_ann_audio_amaps(data_home, index_json_path):
    audio_paths = []
    anno_paths = []
    
    index_df = pd.read_json(index_json_path)
    for piece in index_df.index:
        aud_path = os.path.join(data_home, index_df.audio[piece])
        jams_path = os.path.join(data_home, index_df.jams[piece])
        assert os.path.isfile(aud_path) and os.path.isfile(jams_path)
        audio_paths.append(aud_path)
        anno_paths.append(jams_path)

    paired = list(zip(audio_paths, anno_paths))
    return paired

# %%
output_path = '/Users/tom/Music/A-MAPS_feature/'
data_home = '/Users/tom/Music/A-MAPS/'
index_json = 'dataset_indecies/amaps_index.json'
smkdirs(output_path)

pump = train_utils.make_pump()
stream = tqdm.tqdm(get_ann_audio_amaps(data_home, index_json),
                   desc='Converting audio data')
for aud, jam in stream:
    convert(aud, jam, pump, output_path)
# Out:
# Converting audio data: 100%|██████████| 266/266 [43:01<00:00, 17.87s/it]

# %% [markdown]
# ### Generate mixture set

# %%
index_df = pd.read_json('dataset_indecies/guitarset_index.json')
index_df.keys()
# Out:
# Index(['audio_mic_comp', 'audio_mix_comp', 'jams_comp', 'audio_mic_solo',
#        'audio_mix_solo', 'jams_solo'],
#       dtype='object')

# %%
index_df.audio_mic_comp
# Out:
# 00_BN1-129-Eb    audio_mono-mic/00_BN1-129-Eb_comp_mic.wav
# 00_BN1-147-Gb    audio_mono-mic/00_BN1-147-Gb_comp_mic.wav
# 00_BN2-131-B      audio_mono-mic/00_BN2-131-B_comp_mic.wav
# 00_BN2-166-Ab    audio_mono-mic/00_BN2-166-Ab_comp_mic.wav
# 00_BN3-119-G      audio_mono-mic/00_BN3-119-G_comp_mic.wav
#                                    ...
# 05_SS1-68-E        audio_mono-mic/05_SS1-68-E_comp_mic.wav
# 05_SS2-107-Ab    audio_mono-mic/05_SS2-107-Ab_comp_mic.wav
# 05_SS2-88-F        audio_mono-mic/05_SS2-88-F_comp_mic.wav
# 05_SS3-84-Bb      audio_mono-mic/05_SS3-84-Bb_comp_mic.wav
# 05_SS3-98-C        audio_mono-mic/05_SS3-98-C_comp_mic.wav
# Name: audio_mic_comp, Length: 180, dtype: object

# %%
gs_index = pd.read_json('dataset_indecies/guitarset_index.json')

# %%
gs_index.keys()
# Out:
# Index(['audio_mic_comp', 'audio_mix_comp', 'jams_comp', 'audio_mic_solo',
#        'audio_mix_solo', 'jams_solo'],
#       dtype='object')

# %%
duo_paths = []
for fpath in gs_index.audio_mic_solo:
    duo_path_list = fpath.split('_')
    duo_path_list[-2] = 'duo'
    path = '_'.join(duo_path_list)
    duo_paths.append(path)

# %%
gs_index['audio_mic_duo'] = duo_paths

# %%
gs_index.to_json(path_or_buf='dataset_indecies/guitarset_index.json')

# %%
def get_ann_audio_gs_duo(data_home, index_json_path):
    audio_paths = []
    anno_paths = []
    
    index_df = pd.read_json(index_json_path)
    for piece in index_df.index:
        aud_path = os.path.join(data_home, index_df.audio_mic_duo[piece])
        jams_path = os.path.join(data_home, index_df.jams_solo[piece])
        assert (os.path.isfile(aud_path) and 
                os.path.isfile(jams_path))
        
        audio_paths.append(aud_path)
        anno_paths.append(jams_path)

    pair = list(zip(audio_paths, anno_paths))
    return pair
    
def make_duo(aud_solo, aud_comp, outdir):
    solo, sr = librosa.load(aud_solo, sr=None)
    comp, sr = librosa.load(aud_comp, sr=None)
    
    basename_list = crema.utils.base(aud_solo).split('_')
    basename_list[-2] = 'duo'
    basename = '_'.join(basename_list)
    fname = os.path.extsep.join([os.path.join(outdir, basename),
                                'wav'])
    
    soundfile.write(fname, solo+comp, sr)

# %%
output_path = '/Users/tom/Music/GS_features/'
data_home = '/Users/tom/Music/GuitarSet/'
index_json = 'dataset_indecies/guitarset_index.json'
smkdirs(output_path)

pump = train_utils.make_pump()
stream = tqdm.tqdm(get_ann_audio_gs_duo(data_home, index_json),
                   desc='Converting audio data')

for aud_path, jam in stream:
    convert(aud_path, jam, pump, output_path)
# Out:
# Converting audio data:   0%|          | 0/180 [00:00<?, ?it/s]
#
#
#
# Converting audio data:   1%|          | 1/180 [00:01<04:48,  1.61s/it]
#
#
#
# Converting audio data:   1%|          | 2/180 [00:02<04:27,  1.50s/it]
#
#
#
# Converting audio data:   2%|▏         | 3/180 [00:04<04:34,  1.55s/it]
#
#
#
# Converting audio data:   2%|▏         | 4/180 [00:05<04:23,  1.50s/it]
#
#
#
# Converting audio data:   3%|▎         | 5/180 [00:08<05:13,  1.79s/it]
#
#
#
# Converting audio data:   3%|▎         | 6/180 [00:10<05:21,  1.85s/it]
#
#
#
# Converting audio data:   4%|▍         | 7/180 [00:11<05:03,  1.76s/it]
#
#
#
# Converting audio data:   4%|▍         | 8/180 [00:13<05:19,  1.86s/it]
#
#
#
# Converting audio data:   5%|▌         | 9/180 [00:16<05:36,  1.97s/it]
#
#
#
# Converting audio data:   6%|▌         | 10/180 [00:18<05:54,  2.08s/it]
#
#
#
# Converting audio data:   6%|▌         | 11/180 [00:20<05:51,  2.08s/it]
#
#
#
# Converting audio data:   7%|▋         | 12/180 [00:23<06:33,  2.34s/it]
#
#
#
# Converting audio data:   7%|▋         | 13/180 [00:25<05:51,  2.10s/it]
#
#
#
# Converting audio data:   8%|▊         | 14/180 [00:26<04:56,  1.78s/it]
#
#
#
# Converting audio data:   8%|▊         | 15/180 [00:28<05:11,  1.89s/it]
#
#
#
# Converting audio data:   9%|▉         | 16/180 [00:30<05:04,  1.86s/it]
#
#
#
# Converting audio data:   9%|▉         | 17/180 [00:32<05:44,  2.11s/it]
#
#
#
# Converting audio data:  10%|█         | 18/180 [00:35<05:50,  2.16s/it]
#
#
#
# Converting audio data:  11%|█         | 19/180 [00:36<05:09,  1.92s/it]
#
#
#
# Converting audio data:  11%|█         | 20/180 [00:38<05:24,  2.03s/it]
#
#
#
# Converting audio data:  12%|█▏        | 21/180 [00:40<05:06,  1.93s/it]
#
#
#
# Converting audio data:  12%|█▏        | 22/180 [00:43<05:59,  2.28s/it]
#
#
#
# Converting audio data:  13%|█▎        | 23/180 [00:45<06:06,  2.33s/it]
#
#
#
# Converting audio data:  13%|█▎        | 24/180 [00:47<05:47,  2.23s/it]
#
#
#
# Converting audio data:  14%|█▍        | 25/180 [00:50<05:38,  2.18s/it]
#
#
#
# Converting audio data:  14%|█▍        | 26/180 [00:55<07:52,  3.06s/it]
#
#
#
# Converting audio data:  15%|█▌        | 27/180 [00:57<07:09,  2.81s/it]
#
#
#
# Converting audio data:  16%|█▌        | 28/180 [00:59<06:58,  2.75s/it]
#
#
#
# Converting audio data:  16%|█▌        | 29/180 [01:02<07:05,  2.81s/it]
#
#
#
# Converting audio data:  17%|█▋        | 30/180 [01:06<07:17,  2.91s/it]
#
#
#
# Converting audio data:  17%|█▋        | 31/180 [01:07<06:01,  2.43s/it]
#
#
#
# Converting audio data:  18%|█▊        | 32/180 [01:08<05:07,  2.07s/it]
#
#
#
# Converting audio data:  18%|█▊        | 33/180 [01:11<05:26,  2.22s/it]
#
#
#
# Converting audio data:  19%|█▉        | 34/180 [01:13<05:15,  2.16s/it]
#
#
#
# Converting audio data:  19%|█▉        | 35/180 [01:15<05:07,  2.12s/it]
#
#
#
# Converting audio data:  20%|██        | 36/180 [01:16<04:47,  2.00s/it]
#
#
#
# Converting audio data:  21%|██        | 37/180 [01:18<04:19,  1.82s/it]
#
#
#
# Converting audio data:  21%|██        | 38/180 [01:20<04:12,  1.78s/it]
#
#
#
# Converting audio data:  22%|██▏       | 39/180 [01:22<04:22,  1.86s/it]
#
#
#
# Converting audio data:  22%|██▏       | 40/180 [01:23<04:18,  1.84s/it]
#
#
#
# Converting audio data:  23%|██▎       | 41/180 [01:25<04:25,  1.91s/it]
#
#
#
# Converting audio data:  23%|██▎       | 42/180 [01:28<04:37,  2.01s/it]
#
#
#
# Converting audio data:  24%|██▍       | 43/180 [01:29<04:06,  1.80s/it]
#
#
#
# Converting audio data:  24%|██▍       | 44/180 [01:30<03:32,  1.56s/it]
#
#
#
# Converting audio data:  25%|██▌       | 45/180 [01:32<03:50,  1.71s/it]
#
#
#
# Converting audio data:  26%|██▌       | 46/180 [01:33<03:29,  1.56s/it]
#
#
#
# Converting audio data:  26%|██▌       | 47/180 [01:35<03:33,  1.60s/it]
#
#
#
# Converting audio data:  27%|██▋       | 48/180 [01:36<03:24,  1.55s/it]
#
#
#
# Converting audio data:  27%|██▋       | 49/180 [01:38<03:10,  1.45s/it]
#
#
#
# Converting audio data:  28%|██▊       | 50/180 [01:39<03:22,  1.56s/it]
#
#
#
# Converting audio data:  28%|██▊       | 51/180 [01:41<03:19,  1.55s/it]
#
#
#
# Converting audio data:  29%|██▉       | 52/180 [01:43<03:54,  1.83s/it]
#
#
#
# Converting audio data:  29%|██▉       | 53/180 [01:45<03:50,  1.82s/it]
#
#
#
# Converting audio data:  30%|███       | 54/180 [01:47<03:34,  1.70s/it]
#
#
#
# Converting audio data:  31%|███       | 55/180 [01:48<03:25,  1.64s/it]
#
#
#
# Converting audio data:  31%|███       | 56/180 [01:50<03:43,  1.80s/it]
#
#
#
# Converting audio data:  32%|███▏      | 57/180 [01:52<03:51,  1.88s/it]
#
#
#
# Converting audio data:  32%|███▏      | 58/180 [01:55<04:09,  2.05s/it]
#
#
#
# Converting audio data:  33%|███▎      | 59/180 [01:57<04:24,  2.19s/it]
#
#
#
# Converting audio data:  33%|███▎      | 60/180 [02:00<04:22,  2.19s/it]
#
#
#
# Converting audio data:  34%|███▍      | 61/180 [02:01<03:48,  1.92s/it]
#
#
#
# Converting audio data:  34%|███▍      | 62/180 [02:02<03:16,  1.66s/it]
#
#
#
# Converting audio data:  35%|███▌      | 63/180 [02:04<03:13,  1.65s/it]
#
#
#
# Converting audio data:  36%|███▌      | 64/180 [02:05<03:00,  1.56s/it]
#
#
#
# Converting audio data:  36%|███▌      | 65/180 [02:07<03:08,  1.64s/it]
#
#
#
# Converting audio data:  37%|███▋      | 66/180 [02:08<02:58,  1.56s/it]
#
#
#
# Converting audio data:  37%|███▋      | 67/180 [02:09<02:50,  1.51s/it]
#
#
#
# Converting audio data:  38%|███▊      | 68/180 [02:11<02:58,  1.60s/it]
#
#
#
# Converting audio data:  38%|███▊      | 69/180 [02:13<03:14,  1.75s/it]
#
#
#
# Converting audio data:  39%|███▉      | 70/180 [02:15<03:13,  1.76s/it]
#
#
#
# Converting audio data:  39%|███▉      | 71/180 [02:18<03:31,  1.94s/it]
#
#
#
# Converting audio data:  40%|████      | 72/180 [02:20<03:38,  2.03s/it]
#
#
#
# Converting audio data:  41%|████      | 73/180 [02:21<03:23,  1.90s/it]
#
#
#
# Converting audio data:  41%|████      | 74/180 [02:22<02:47,  1.58s/it]
#
#
#
# Converting audio data:  42%|████▏     | 75/180 [02:24<03:03,  1.74s/it]
#
#
#
# Converting audio data:  42%|████▏     | 76/180 [02:26<02:44,  1.58s/it]
#
#
#
# Converting audio data:  43%|████▎     | 77/180 [02:27<02:42,  1.58s/it]
#
#
#
# Converting audio data:  43%|████▎     | 78/180 [02:29<02:36,  1.53s/it]
#
#
#
# Converting audio data:  44%|████▍     | 79/180 [02:31<02:59,  1.78s/it]
#
#
#
# Converting audio data:  44%|████▍     | 80/180 [02:33<02:59,  1.80s/it]
#
#
#
# Converting audio data:  45%|████▌     | 81/180 [02:34<02:50,  1.72s/it]
#
#
#
# Converting audio data:  46%|████▌     | 82/180 [02:37<03:11,  1.95s/it]
#
#
#
# Converting audio data:  46%|████▌     | 83/180 [02:39<03:05,  1.91s/it]
#
#
#
# Converting audio data:  47%|████▋     | 84/180 [02:40<02:50,  1.78s/it]
#
#
#
# Converting audio data:  47%|████▋     | 85/180 [02:42<02:47,  1.76s/it]
#
#
#
# Converting audio data:  48%|████▊     | 86/180 [02:44<03:04,  1.96s/it]
#
#
#
# Converting audio data:  48%|████▊     | 87/180 [02:46<03:07,  2.02s/it]
#
#
#
# Converting audio data:  49%|████▉     | 88/180 [02:49<03:19,  2.17s/it]
#
#
#
# Converting audio data:  49%|████▉     | 89/180 [02:51<03:29,  2.30s/it]
#
#
#
# Converting audio data:  50%|█████     | 90/180 [02:54<03:24,  2.27s/it]
#
#
#
# Converting audio data:  51%|█████     | 91/180 [02:55<02:54,  1.96s/it]
#
#
#
# Converting audio data:  51%|█████     | 92/180 [02:56<02:31,  1.72s/it]
#
#
#
# Converting audio data:  52%|█████▏    | 93/180 [02:58<02:26,  1.69s/it]
#
#
#
# Converting audio data:  52%|█████▏    | 94/180 [02:59<02:13,  1.55s/it]
#
#
#
# Converting audio data:  53%|█████▎    | 95/180 [03:01<02:16,  1.61s/it]
#
#
#
# Converting audio data:  53%|█████▎    | 96/180 [03:02<02:15,  1.61s/it]
#
#
#
# Converting audio data:  54%|█████▍    | 97/180 [03:04<02:09,  1.56s/it]
#
#
#
# Converting audio data:  54%|█████▍    | 98/180 [03:06<02:28,  1.81s/it]
#
#
#
# Converting audio data:  55%|█████▌    | 99/180 [03:09<02:42,  2.00s/it]
#
#
#
# Converting audio data:  56%|█████▌    | 100/180 [03:11<02:43,  2.04s/it]
#
#
#
# Converting audio data:  56%|█████▌    | 101/180 [03:13<02:42,  2.06s/it]
#
#
#
# Converting audio data:  57%|█████▋    | 102/180 [03:15<02:50,  2.19s/it]
#
#
#
# Converting audio data:  57%|█████▋    | 103/180 [03:17<02:33,  1.99s/it]
#
#
#
# Converting audio data:  58%|█████▊    | 104/180 [03:18<02:06,  1.66s/it]
#
#
#
# Converting audio data:  58%|█████▊    | 105/180 [03:20<02:25,  1.94s/it]
#
#
#
# Converting audio data:  59%|█████▉    | 106/180 [03:22<02:11,  1.77s/it]
#
#
#
# Converting audio data:  59%|█████▉    | 107/180 [03:23<02:07,  1.75s/it]
#
#
#
# Converting audio data:  60%|██████    | 108/180 [03:25<02:02,  1.70s/it]
#
#
#
# Converting audio data:  61%|██████    | 109/180 [03:26<01:55,  1.62s/it]
#
#
#
# Converting audio data:  61%|██████    | 110/180 [03:28<02:02,  1.75s/it]
#
#
#
# Converting audio data:  62%|██████▏   | 111/180 [03:30<01:58,  1.72s/it]
#
#
#
# Converting audio data:  62%|██████▏   | 112/180 [03:33<02:13,  1.97s/it]
#
#
#
# Converting audio data:  63%|██████▎   | 113/180 [03:35<02:12,  1.97s/it]
#
#
#
# Converting audio data:  63%|██████▎   | 114/180 [03:36<01:58,  1.79s/it]
#
#
#
# Converting audio data:  64%|██████▍   | 115/180 [03:38<01:56,  1.79s/it]
#
#
#
# Converting audio data:  64%|██████▍   | 116/180 [03:40<02:03,  1.93s/it]
#
#
#
# Converting audio data:  65%|██████▌   | 117/180 [03:42<01:59,  1.90s/it]
#
#
#
# Converting audio data:  66%|██████▌   | 118/180 [03:44<02:07,  2.06s/it]
#
#
#
# Converting audio data:  66%|██████▌   | 119/180 [03:47<02:13,  2.18s/it]
#
#
#
# Converting audio data:  67%|██████▋   | 120/180 [03:49<02:09,  2.16s/it]
#
#
#
# Converting audio data:  67%|██████▋   | 121/180 [03:50<01:51,  1.89s/it]
#
#
#
# Converting audio data:  68%|██████▊   | 122/180 [03:51<01:36,  1.67s/it]
#
#
#
# Converting audio data:  68%|██████▊   | 123/180 [03:53<01:34,  1.66s/it]
#
#
#
# Converting audio data:  69%|██████▉   | 124/180 [03:54<01:26,  1.55s/it]
#
#
#
# Converting audio data:  69%|██████▉   | 125/180 [03:56<01:28,  1.62s/it]
#
#
#
# Converting audio data:  70%|███████   | 126/180 [03:57<01:23,  1.55s/it]
#
#
#
# Converting audio data:  71%|███████   | 127/180 [03:59<01:22,  1.55s/it]
#
#
#
# Converting audio data:  71%|███████   | 128/180 [04:01<01:23,  1.60s/it]
#
#
#
# Converting audio data:  72%|███████▏  | 129/180 [04:03<01:28,  1.73s/it]
#
#
#
# Converting audio data:  72%|███████▏  | 130/180 [04:04<01:26,  1.73s/it]
#
#
#
# Converting audio data:  73%|███████▎  | 131/180 [04:06<01:26,  1.76s/it]
#
#
#
# Converting audio data:  73%|███████▎  | 132/180 [04:08<01:30,  1.89s/it]
#
#
#
# Converting audio data:  74%|███████▍  | 133/180 [04:10<01:21,  1.73s/it]
#
#
#
# Converting audio data:  74%|███████▍  | 134/180 [04:11<01:07,  1.48s/it]
#
#
#
# Converting audio data:  75%|███████▌  | 135/180 [04:13<01:12,  1.61s/it]
#
#
#
# Converting audio data:  76%|███████▌  | 136/180 [04:14<01:05,  1.48s/it]
#
#
#
# Converting audio data:  76%|███████▌  | 137/180 [04:16<01:07,  1.56s/it]
#
#
#
# Converting audio data:  77%|███████▋  | 138/180 [04:17<01:05,  1.55s/it]
#
#
#
# Converting audio data:  77%|███████▋  | 139/180 [04:18<01:00,  1.47s/it]
#
#
#
# Converting audio data:  78%|███████▊  | 140/180 [04:20<01:01,  1.53s/it]
#
#
#
# Converting audio data:  78%|███████▊  | 141/180 [04:22<01:01,  1.58s/it]
#
#
#
# Converting audio data:  79%|███████▉  | 142/180 [04:24<01:09,  1.84s/it]
#
#
#
# Converting audio data:  79%|███████▉  | 143/180 [04:26<01:09,  1.89s/it]
#
#
#
# Converting audio data:  80%|████████  | 144/180 [04:28<01:03,  1.76s/it]
#
#
#
# Converting audio data:  81%|████████  | 145/180 [04:29<00:58,  1.68s/it]
#
#
#
# Converting audio data:  81%|████████  | 146/180 [04:31<01:03,  1.85s/it]
#
#
#
# Converting audio data:  82%|████████▏ | 147/180 [04:34<01:12,  2.19s/it]
#
#
#
# Converting audio data:  82%|████████▏ | 148/180 [04:37<01:11,  2.25s/it]
#
#
#
# Converting audio data:  83%|████████▎ | 149/180 [04:39<01:11,  2.32s/it]
#
#
#
# Converting audio data:  83%|████████▎ | 150/180 [04:41<01:07,  2.25s/it]
#
#
#
# Converting audio data:  84%|████████▍ | 151/180 [04:43<00:56,  1.95s/it]
#
#
#
# Converting audio data:  84%|████████▍ | 152/180 [04:44<00:46,  1.68s/it]
#
#
#
# Converting audio data:  85%|████████▌ | 153/180 [04:45<00:45,  1.68s/it]
#
#
#
# Converting audio data:  86%|████████▌ | 154/180 [04:47<00:41,  1.59s/it]
#
#
#
# Converting audio data:  86%|████████▌ | 155/180 [04:48<00:41,  1.66s/it]
#
#
#
# Converting audio data:  87%|████████▋ | 156/180 [04:50<00:37,  1.58s/it]
#
#
#
# Converting audio data:  87%|████████▋ | 157/180 [04:51<00:34,  1.50s/it]
#
#
#
# Converting audio data:  88%|████████▊ | 158/180 [04:53<00:33,  1.52s/it]
#
#
#
# Converting audio data:  88%|████████▊ | 159/180 [04:55<00:35,  1.68s/it]
#
#
#
# Converting audio data:  89%|████████▉ | 160/180 [04:57<00:33,  1.70s/it]
#
#
#
# Converting audio data:  89%|████████▉ | 161/180 [04:58<00:33,  1.75s/it]
#
#
#
# Converting audio data:  90%|█████████ | 162/180 [05:00<00:33,  1.84s/it]
#
#
#
# Converting audio data:  91%|█████████ | 163/180 [05:02<00:27,  1.65s/it]
#
#
#
# Converting audio data:  91%|█████████ | 164/180 [05:02<00:22,  1.39s/it]
#
#
#
# Converting audio data:  92%|█████████▏| 165/180 [05:04<00:23,  1.58s/it]
#
#
#
# Converting audio data:  92%|█████████▏| 166/180 [05:06<00:20,  1.45s/it]
#
#
#
# Converting audio data:  93%|█████████▎| 167/180 [05:07<00:19,  1.47s/it]
#
#
#
# Converting audio data:  93%|█████████▎| 168/180 [05:09<00:17,  1.45s/it]
#
#
#
# Converting audio data:  94%|█████████▍| 169/180 [05:10<00:15,  1.38s/it]
#
#
#
# Converting audio data:  94%|█████████▍| 170/180 [05:11<00:14,  1.47s/it]
#
#
#
# Converting audio data:  95%|█████████▌| 171/180 [05:13<00:13,  1.54s/it]
#
#
#
# Converting audio data:  96%|█████████▌| 172/180 [05:16<00:14,  1.80s/it]
#
#
#
# Converting audio data:  96%|█████████▌| 173/180 [05:18<00:13,  1.90s/it]
#
#
#
# Converting audio data:  97%|█████████▋| 174/180 [05:19<00:10,  1.78s/it]
#
#
#
# Converting audio data:  97%|█████████▋| 175/180 [05:21<00:08,  1.69s/it]
#
#
#
# Converting audio data:  98%|█████████▊| 176/180 [05:23<00:07,  1.82s/it]
#
#
#
# Converting audio data:  98%|█████████▊| 177/180 [05:25<00:05,  1.86s/it]
#
#
#
# Converting audio data:  99%|█████████▉| 178/180 [05:27<00:04,  2.00s/it]
#
#
#
# Converting audio data:  99%|█████████▉| 179/180 [05:29<00:02,  2.13s/it]
#
#
#
# Converting audio data: 100%|██████████| 180/180 [05:32<00:00,  2.12s/it]

# %%
np.roll([1, 2, 3, 4, 5], 2)
# Out:
# array([4, 5, 1, 2, 3])
